# %%
f=x^3-9*x^2+27*x+50
plot(f, (x, -10, 10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f.roots()
# Out:
# [(-1/2*77^(1/3)*(-1)^(1/3)*(I*sqrt(3) + 1) + 3, 1),
#  (-1/2*77^(1/3)*(-1)^(1/3)*(-I*sqrt(3) + 1) + 3, 1),
#  (77^(1/3)*(-1)^(1/3) + 3, 1)]
